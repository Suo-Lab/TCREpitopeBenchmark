# %% [markdown]
# # Original model prediction

# %%
import numpy as np
import pandas as pd
import collections
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from SETE import *
from itertools import cycle
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from scipy import interp
from sklearn.base import clone
from sklearn.decomposition import PCA, KernelPCA
from sklearn.cross_decomposition import CCA

from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import GradientBoostingClassifier

import warnings

warnings.filterwarnings('ignore')

import collections
from collections import Counter

def kemr_count(df, k_size):
    genes_seq = df[["ID", "CDR3B"]].set_index("ID").to_dict(orient='dict')["CDR3B"]
    def build_kmers(seq, k_size):
        kmers = []  
        n_kmers = len(seq) - k_size + 1
        for i in range(n_kmers):
            kmer = seq[i:i + k_size]
            kmers.append(kmer)
        return kmers
    def summary_kmers(kmers):
        kmers_stat = dict(Counter(kmers))
        return kmers_stat   
    genes_kmers = {}
    for gene in genes_seq.keys():
        genes_kmers[gene] = summary_kmers(build_kmers(seq=genes_seq[gene], k_size=k_size))
    Kmer_tcrcount = pd.DataFrame(genes_kmers).T
    return Kmer_tcrcount

def blast(df, count_size):
    seq = 'GAVLIPFYWSTCMNQDEKRH'
    index = []
    for i in seq:
        for j in seq:
            for z in seq:
                a = i + j + z
                index.append(a)
    count = np.zeros((len(df), count_size))
    count = pd.DataFrame(count)
    count.columns = index
    count.index = df.ID
    return count

def replacement(df1, df2):
    common_cols = list(set(df1.columns) & set(df2.columns))
    df2.loc[:, common_cols] = df1.loc[:, common_cols]
    return df2

def k_mer(df, k_size, count_size):
    Kmer_tcrcount = kemr_count(df, k_size)
    count = blast(df, count_size)
    k_mer = replacement(Kmer_tcrcount, count)
    k_mer = np.array(k_mer.fillna(0))
    return k_mer

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, matthews_corrcoef, precision_score,recall_score
import pickle
def pca_analyse(X_train, X_test, rate=0.8):
    """Perform PCA for the train set and test set."""
    pca = PCA(n_components=rate).fit(X_train)
    return pca.transform(X_train), pca.transform(X_test)

def train_main(trainfile_path,testfile_path,save_model_path,result_path):
    train = pd.read_csv(trainfile_path)
    train=train[train['Epitope'].isin(['GILGFVFTL', 'GLCTLVAML', 'NLVPMVATV'])]
    test = pd.read_csv(testfile_path)
    epitope = pd.unique(train['Epitope'])
    # Initialize results_df outside of the loop
    results_list = []
    probab_list=[]
    for i in epitope:
        df_train = train[train['Epitope'] == i].sample(frac=1, random_state=42)  # Filter the dataframe for current epitope
        df_train['ID'] = range(1, len(df_train) + 1)
        X_train = k_mer(df_train, 3, 8000)
        y_train = df_train['Affinity'].values
        df_test = test[test['Epitope'] == i].sample(frac=1, random_state=42)  # Filter the dataframe for current epitope
        df_test['ID'] = range(1, len(df_test) + 1)
        X_test = k_mer(df_test, 3, 8000)
        y_test = df_test['Affinity'].values
        classifier = OneVsRestClassifier(
            GradientBoostingClassifier(
                learning_rate=0.1,
                min_samples_leaf=20,
                max_features='sqrt',
                subsample=0.8,
                random_state=10,
                n_estimators=70,
                max_depth=10,
                min_samples_split=60,
                loss="deviance" ))
        X_train, X_test = pca_analyse(X_train, X_test, 0.8)
        classifier.fit(X_train, y_train)
        with open(save_model_path+i+'model.pkl', 'wb') as file:
            pickle.dump(classifier, file)
        y_pred = classifier.predict(X_test)
        classifier.score(X_test, y_test)
        y_prob = classifier.predict_proba(X_test)[:, -1]
        probab= { 'Epitope': [i] * len(df_test['CDR3B']),'CDR3B': df_test['CDR3B'],'y_true': y_test, 'y_pred': y_pred,'y_prob': y_prob}
        probab_list.append(probab)   
        probability = pd.DataFrame(probab_list)
        probability = pd.DataFrame(probability)
        probability = probability.apply(pd.Series.explode)
        probability.to_csv(result_path+'probability.csv')

# %%
import pandas as pd
name=['1','2','3']
me=['health','Diseases','antigen_specificity']
for i in name:
    for j in me:
        trainfile_path ="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/data/train_raw_data.csv"
        testfile_path= "/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/Prediction/all/seen/three/neg_pos/"+i+'_'+j+'.csv'
        save_model_path= "/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/model/Original_Model/"
        result_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/result/Original_Model/seen/three/"+i+'_'+j
        train_main(trainfile_path,testfile_path,save_model_path,result_path)

# %% [markdown]
# # Model retraining

# %%
import numpy as np
import pandas as pd
import collections
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from SETE import *
from itertools import cycle
from sklearn.metrics import roc_curve, auc, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier
from scipy import interp
from sklearn.base import clone
from sklearn.decomposition import PCA, KernelPCA
from sklearn.cross_decomposition import CCA

from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import GradientBoostingClassifier

import warnings

warnings.filterwarnings('ignore')

# %%
import collections
from collections import Counter

def kemr_count(df, k_size):
    genes_seq = df[["ID", "CDR3B"]].set_index("ID").to_dict(orient='dict')["CDR3B"]
    def build_kmers(seq, k_size):
        kmers = []  
        n_kmers = len(seq) - k_size + 1
        for i in range(n_kmers):
            kmer = seq[i:i + k_size]
            kmers.append(kmer)
        return kmers
    def summary_kmers(kmers):
        kmers_stat = dict(Counter(kmers))
        return kmers_stat   
    genes_kmers = {}
    for gene in genes_seq.keys():
        genes_kmers[gene] = summary_kmers(build_kmers(seq=genes_seq[gene], k_size=k_size))
    Kmer_tcrcount = pd.DataFrame(genes_kmers).T
    return Kmer_tcrcount

def blast(df, count_size):
    seq = 'GAVLIPFYWSTCMNQDEKRH'
    index = []
    for i in seq:
        for j in seq:
            for z in seq:
                a = i + j + z
                index.append(a)
    count = np.zeros((len(df), count_size))
    count = pd.DataFrame(count)
    count.columns = index
    count.index = df.ID
    return count

def replacement(df1, df2):
    common_cols = list(set(df1.columns) & set(df2.columns))
    df2.loc[:, common_cols] = df1.loc[:, common_cols]
    return df2

def k_mer(df, k_size, count_size):
    Kmer_tcrcount = kemr_count(df, k_size)
    count = blast(df, count_size)
    k_mer = replacement(Kmer_tcrcount, count)
    k_mer = np.array(k_mer.fillna(0))
    return k_mer

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, matthews_corrcoef, precision_score,recall_score
import pickle
def pca_analyse(X_train, X_test, rate=0.8):
    """Perform PCA for the train set and test set."""
    pca = PCA(n_components=rate).fit(X_train)
    return pca.transform(X_train), pca.transform(X_test)

def train_main(trainfile_path,testfile_path,save_model_path,result_path):
    train = pd.read_csv(trainfile_path)
    test = pd.read_csv(testfile_path)
    epitope = pd.unique(test['Epitope'])
    # Initialize results_df outside of the loop
    results_list = []
    probab_list=[]
    for i in epitope:
        df_train = train[train['Epitope'] == i].sample(frac=1, random_state=42)  # Filter the dataframe for current epitope
        df_train['ID'] = range(1, len(df_train) + 1)
        X_train = k_mer(df_train, 3, 8000)
        y_train = df_train['Affinity'].values
        df_test = test[test['Epitope'] == i].sample(frac=1, random_state=42)  # Filter the dataframe for current epitope
        df_test['ID'] = range(1, len(df_test) + 1)
        X_test = k_mer(df_test, 3, 8000)
        y_test = df_test['Affinity'].values
        classifier = OneVsRestClassifier(
            GradientBoostingClassifier(
                learning_rate=0.1,
                min_samples_leaf=20,
                max_features='sqrt',
                subsample=0.8,
                random_state=10,
                n_estimators=70,
                max_depth=10,
                min_samples_split=60,
                loss="deviance" ))
        X_train, X_test = pca_analyse(X_train, X_test, 0.8)
        classifier.fit(X_train, y_train)
        with open(save_model_path+i+'model.pkl', 'wb') as file:
            pickle.dump(classifier, file)
        y_pred = classifier.predict(X_test)
        classifier.score(X_test, y_test)
        y_prob = classifier.predict_proba(X_test)[:, -1]
        probab= { 'Epitope': [i] * len(df_test['CDR3B']),'CDR3B': df_test['CDR3B'],'y_true': y_test, 'y_pred': y_pred,'y_prob': y_prob}     
        probab_list.append(probab)   
        probability = pd.DataFrame(probab_list)
        probability = pd.DataFrame(probability)
        probability = probability.apply(pd.Series.explode)
        probability.to_csv(result_path+'probability.csv')

# %%
database=['Antigen_specificity']
name1=['1','2','3','4','5']
name=['1_1','1_2','1_4']
for i in database:
    for j in name:
        for k in name1:
            trainfile_path ="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair50/"+i+"/"+k+'_'+j+"train.csv"
            save_model_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/model/Retrain/pair50/"+i+"/"+k+'_'+j
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/Validation/"+i+"/"+k+'_'+"1_1Validation.csv"
            result_path="./result/pair50/seen/validation/"+i+"/"+k+'_'+j
            train_main(trainfile_path,testfile_path,save_model_path,result_path)

# %%
import multiprocessing
num_cores = 50
pool = multiprocessing.Pool(num_cores)

# %% [markdown]
# # pair50

# %%
database=['healthy','patient']
name1=['1','2','3','4','5']
name=['1_1','1_2','1_4','1_6','1_8']
for i in database:
    for j in name:
        for k in name1:
            trainfile_path ="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair50/"+i+"/"+k+'_'+j+"train.csv"
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair50/"+i+"/"+k+'_'+"1_1test.csv"
            save_model_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/model/Retrain/pair50/"+i+"/"+k+'_'+j
            result_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/result/pair50/seen/test/"+i+"/"+k+'_'+j
            train_main(trainfile_path,testfile_path,save_model_path,result_path)  
            
database=['Antigen_specificity']
name1=['1','2','3','4','5']
name=['1_1','1_2','1_4']
for i in database:
    for j in name:
        for k in name1:
            trainfile_path ="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair50/"+i+"/"+k+'_'+j+"train.csv"
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair50/"+i+"/"+k+'_'+"1_1test.csv"
            save_model_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/model/Retrain/pair50/"+i+"/"+k+'_'+j
            result_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/result/pair50/seen/test/"+i+"/"+k+'_'+j
            train_main(trainfile_path,testfile_path,save_model_path,result_path)

# %% [markdown]
# # pair300

# %%
pair=['more300','300','200','100','10']
database=['healthy','patient','Antigen_specificity']
name1=['1','2','3','4','5']
name=['1_1']
for i in database:
    for j in name:
        for k in name1:
            for l in pair:
                trainfile_path ="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair300/"+l+"/"+i+"/"+k+'_'+j+"train.csv"
                testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/pair300/more300/"+i+"/"+k+'_'+"1_1test.csv"
                save_model_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/model/Retrain/pair300/seen/"+l+"/"+i+"/"+k+'_'+j
                result_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/result/pair300/seen/"+l+"/"+i+"/"+k+'_'+j
                train_main(trainfile_path,testfile_path,save_model_path,result_path)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[5], line 13
#      11 save_model_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/model/Retrain/pair300/seen/"+l+"/"+i+"/"+k+'_'+j
#      12 result_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/result/pair300/seen/"+l+"/"+i+"/"+k+'_'+j
# ---> 13 train_main(trainfile_path,testfile_path,save_model_path,result_path)
#
# Cell In[3], line 35, in train_main(trainfile_path, testfile_path, save_model_path, result_path)
#      23 y_test = df_test['Affinity'].values
#      24 classifier = OneVsRestClassifier(
#      25     GradientBoostingClassifier(
#      26         learning_rate=0.1,
#    (...)
#      33         min_samples_split=60,
#      34         loss="deviance" ))
# ---> 35 X_train, X_test = pca_analyse(X_train, X_test, 0.8)
#      36 classifier.fit(X_train, y_train)
#      37 with open(save_model_path+i+'model.pkl', 'wb') as file:
#
# Cell In[3], line 5, in pca_analyse(X_train, X_test, rate)
#       3 def pca_analyse(X_train, X_test, rate=0.9):
#       4     """Perform PCA for the train set and test set."""
# ----> 5     pca = PCA(n_components=rate).fit(X_train)
#       6     return pca.transform(X_train), pca.transform(X_test)
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:483, in PCA._fit(self, X)
#     481 # Call different fits for either full or truncated SVD
#     482 if self._fit_svd_solver == "full":
# --> 483     return self._fit_full(X, n_components)
#     484 elif self._fit_svd_solver in ["arpack", "randomized"]:
#     485     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:518, in PCA._fit_full(self, X, n_components)
#     515 self.mean_ = np.mean(X, axis=0)
#     516 X -= self.mean_
# --> 518 U, S, Vt = linalg.svd(X, full_matrices=False)
#     519 # flip eigenvectors' sign to enforce deterministic output
#     520 U, Vt = svd_flip(U, Vt)
#
# File ~/miniconda3/lib/python3.8/site-packages/scipy/linalg/_decomp_svd.py:131, in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     127 u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
#     128                       full_matrices=full_matrices, overwrite_a=overwrite_a)
#     130 if info > 0:
# --> 131     raise LinAlgError("SVD did not converge")
#     132 if info < 0:
#     133     raise ValueError('illegal value in %dth argument of internal gesdd'
#     134                      % -info)
#
# LinAlgError: SVD did not converge

# %% [markdown]
# # validaiton

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, matthews_corrcoef, precision_score, recall_score
import pickle
import pandas as pd

def pca_analyse(X_train, X_test, rate=0.9):
    """Perform PCA for the train set and test set."""
    pca = PCA(n_components=rate).fit(X_train)
    return pca.transform(X_train), pca.transform(X_test)
def train_main( testfile_path, modelfile_path, result_path):
    test = pd.read_csv(testfile_path)
    epitope = pd.unique(test['Epitope'])
    probab_list = []
    for i in epitope:
        df_test = test[test['Epitope'] == i].sample(frac=1, random_state=42)
        df_test['ID'] = range(1, len(df_test) + 1)
        X_test = k_mer(df_test, 3, 8000)
        y_test = df_test['Affinity'].values
        model_path = modelfile_path + i + 'model.pkl'
        with open(model_path, 'rb') as file:
            classifier = pickle.load(file)
        _, X_test = pca_analyse(X_test, X_test, 0.8)
        y_pred = classifier.predict(X_test)
        y_prob = classifier.predict_proba(X_test)[:, -1]
        probab = {
            'Epitope': [i] * len(df_test['CDR3B']),
            'CDR3B': df_test['CDR3B'],
            'y_true': y_test,
            'y_pred': y_pred,
            'y_prob': y_prob
        }
        probab_list.append(probab)
    probability = pd.DataFrame(probab_list)
    probability = probability.apply(pd.Series.explode)
    probability.to_csv(result_path + 'probability.csv', index=False)

# %%
database=['Antigen_specificity']
name1=['1','2','3','4','5']
name=['1_1','1_2','1_4']
for i in database:
    for j in name:
        for k in name1:
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/Validation/"+i+"/"+k+'_'+"1_1Validation.csv"
            modelfile_path="./model/Retrain/pair50/"+i+"/"+k+'_'+j
            result_path="./result/pair50/seen/validation/"+i+"/"+k+'_'+j
            train_main(testfile_path,modelfile_path,result_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       8 modelfile_path="./model/Retrain/pair50/"+i+"/"+k+'_'+j
#       9 result_path="./result/pair50/seen/validation/"+i+"/"+k+'_'+j
# ---> 10 train_main(testfile_path,modelfile_path,result_path)
#
# Cell In[7], line 22, in train_main(testfile_path, modelfile_path, result_path)
#      20     classifier = pickle.load(file)
#      21 _, X_test = pca_analyse(X_test, X_test, 0.8)
# ---> 22 y_pred = classifier.predict(X_test)
#      23 y_prob = classifier.predict_proba(X_test)[:, -1]
#      24 probab = {
#      25     'Epitope': [i] * len(df_test['CDR3B']),
#      26     'CDR3B': df_test['CDR3B'],
#    (...)
#      29     'y_prob': y_prob
#      30 }
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/multiclass.py:442, in OneVsRestClassifier.predict(self, X)
#     440 indptr = array.array("i", [0])
#     441 for e in self.estimators_:
# --> 442     indices.extend(np.where(_predict_binary(e, X) > thresh)[0])
#     443     indptr.append(len(indices))
#     444 data = np.ones(len(indices), dtype=int)
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/multiclass.py:98, in _predict_binary(estimator, X)
#      96     return estimator.predict(X)
#      97 try:
# ---> 98     score = np.ravel(estimator.decision_function(X))
#      99 except (AttributeError, NotImplementedError):
#     100     # probabilities of the positive class
#     101     score = estimator.predict_proba(X)[:, 1]
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:1405, in GradientBoostingClassifier.decision_function(self, X)
#    1386 def decision_function(self, X):
#    1387     """Compute the decision function of ``X``.
#    1388
#    1389     Parameters
#    (...)
#    1403         array of shape (n_samples,).
#    1404     """
# -> 1405     X = self._validate_data(
#    1406         X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#    1407     )
#    1408     raw_predictions = self._raw_predict(X)
#    1409     if raw_predictions.shape[1] == 1:
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 290 features, but GradientBoostingClassifier is expecting 602 features as input.

# %% [markdown]
# # validaiton

# %%
database=['healthy','patient']
name1=['1','2','3','4','5']
name=['1_1','1_2','1_4','1_6','1_8']
for i in database:
    for j in name:
        for k in name1:
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/Validation/"+i+"/"+k+'_'+"1_1Validation.csv"
            modelfile_path="./model/Retrain/pair50/"+i+"/"+k+'_'+j
            result_path="./result/pair50/seen/validation/"+i+"/"+k+'_'+j
            train_main(testfile_path,modelfile_path, result_path) 

database=['Antigen_specificity']
name1=['1','2','3','4','5']
name=['1_1','1_2','1_4']
for i in database:
    for j in name:
        for k in name1:
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/Validation/"+i+"/"+k+'_'+"1_1Validation.csv"
            modelfile_path="./model/Retrain/pair50/"+i+"/"+k+'_'+j
            result_path="./result/pair50/seen/validation/"+i+"/"+k+'_'+j
            train_main(testfile_path,modelfile_path,result_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 10
#       8             modelfile_path="./model/Retrain/pair50/"+i+"/"+k+'_'+j
#       9             result_path="./result/pair50/seen/validation/"+i+"/"+k+'_'+j
# ---> 10             train_main(testfile_path,modelfile_path, result_path)
#      12 database=['Antigen_specificity']
#      13 name1=['1','2','3','4','5']
#
# Cell In[5], line 25, in train_main(testfile_path, model_dir, result_path)
#      23     classifier = pickle.load(file)
#      24 _, X_test = pca_analyse(X_test, X_test, 0.8)
# ---> 25 y_pred = classifier.predict(X_test)
#      26 y_prob = classifier.predict_proba(X_test)[:, -1]
#      28 probab = {
#      29     'Epitope': [i] * len(df_test['CDR3B']),
#      30     'CDR3B': df_test['CDR3B'],
#    (...)
#      33     'y_prob': y_prob
#      34 }
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/multiclass.py:442, in OneVsRestClassifier.predict(self, X)
#     440 indptr = array.array("i", [0])
#     441 for e in self.estimators_:
# --> 442     indices.extend(np.where(_predict_binary(e, X) > thresh)[0])
#     443     indptr.append(len(indices))
#     444 data = np.ones(len(indices), dtype=int)
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/multiclass.py:98, in _predict_binary(estimator, X)
#      96     return estimator.predict(X)
#      97 try:
# ---> 98     score = np.ravel(estimator.decision_function(X))
#      99 except (AttributeError, NotImplementedError):
#     100     # probabilities of the positive class
#     101     score = estimator.predict_proba(X)[:, 1]
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:1405, in GradientBoostingClassifier.decision_function(self, X)
#    1386 def decision_function(self, X):
#    1387     """Compute the decision function of ``X``.
#    1388
#    1389     Parameters
#    (...)
#    1403         array of shape (n_samples,).
#    1404     """
# -> 1405     X = self._validate_data(
#    1406         X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#    1407     )
#    1408     raw_predictions = self._raw_predict(X)
#    1409     if raw_predictions.shape[1] == 1:
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File ~/miniconda3/lib/python3.8/site-packages/sklearn/base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 334 features, but GradientBoostingClassifier is expecting 696 features as input.

# %% [markdown]
# # top5

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, matthews_corrcoef, precision_score,recall_score
import pickle
def pca_analyse(X_train, X_test, rate=0.8):
    """Perform PCA for the train set and test set."""
    pca = PCA(n_components=rate).fit(X_train)
    return pca.transform(X_train), pca.transform(X_test)

def train_main(trainfile_path,testfile_path,result_path):
    train = pd.read_csv(trainfile_path)
    test = pd.read_csv(testfile_path)
    epitope = pd.unique(train['Epitope'])
    results_list = []
    probab_list=[]
    for i in epitope:
        df_train = train[train['Epitope'] == i].sample(frac=1, random_state=42)  # Filter the dataframe for current epitope
        df_train['ID'] = range(1, len(df_train) + 1)
        X_train = k_mer(df_train, 3, 8000)
        y_train = df_train['Affinity'].values
        df_test = test[test['Epitope'] == i].sample(frac=1, random_state=42)  # Filter the dataframe for current epitope
        df_test['ID'] = range(1, len(df_test) + 1)
        X_test = k_mer(df_test, 3, 8000)
        y_test = df_test['Affinity'].values
        classifier = OneVsRestClassifier(
            GradientBoostingClassifier(
                learning_rate=0.1,
                min_samples_leaf=20,
                max_features='sqrt',
                subsample=0.8,
                random_state=10,
                n_estimators=70,
                max_depth=10,
                min_samples_split=60,
                loss="deviance" ))
        X_train, X_test = pca_analyse(X_train, X_test, 0.8)
        classifier.fit(X_train, y_train)
        y_pred = classifier.predict(X_test)
        classifier.score(X_test, y_test)
        y_prob = classifier.predict_proba(X_test)[:, -1]
        probab= { 'Epitope': [i] * len(df_test['CDR3B']),'CDR3B': df_test['CDR3B'],'y_true': y_test, 'y_pred': y_pred,'y_prob': y_prob}     
        probab_list.append(probab)   
        probability = pd.DataFrame(probab_list)
        probability = pd.DataFrame(probability)
        probability = probability.apply(pd.Series.explode)
        probability.to_csv(result_path+'probability.csv')

# %%
reap=['reap1','reap2','reap3','reap4','reap5']
name=['top1','top2','top3','top4','top5']
number= ['3000', '2800', '2600', '2400', '2200', '2000', '1800', '1600', '1400', '1200', '1000', '800', '600', '400', '200', '50']
for i in reap:
    for j in name:
        for k in number:
            trainfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/top5/healthy/"+i+"_" +j+"_"+k+'.csv'
            testfile_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/database/benchmark_dataset/10cross_validation/top5/healthy/"+i+"_" +j+"_"+'test.csv'    
            result_path="/home/luyanping/data/TCR_epitope_prediction/Compare_models_same_data/SETE/result/top5/seen/healthy/"+i+'_'+j+'_'+k
            train_main(trainfile_path,testfile_path,result_path)
